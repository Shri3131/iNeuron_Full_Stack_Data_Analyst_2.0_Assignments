# %% [markdown]
# ### Use the below table for the following Questions.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. Find the Minimum Marks and Maximum marks scored by each student.

# %% [markdown]
# #### Ans:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 2. Calculate the totals for each student, use conditional formatting to highlight the top students who have scored more than 480.

# %% [markdown]
# #### Ans:
# As per given data no student scored 480
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 3. Calculate the length of the names of each student.

# %% [markdown]
# #### Ans:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Replace the Name Rakhi with Rocky. Use Formulas

# %% [markdown]
# #### Ans:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. Combine the Roll Numbers and Names. Use formulas. The end result should look like below.
# ### 100101Rohan

# %% [markdown]
# #### Ans:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. As you can see that some names have spacing issues. Use Formulasto correct that spacing. Also ensure that the names and surnames start with a capital letter

# %% [markdown]
# #### Ans:
#
# ![image.png](attachment:image.png)
