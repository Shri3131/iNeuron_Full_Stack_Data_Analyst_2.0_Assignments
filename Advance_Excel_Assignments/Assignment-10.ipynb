# %% [markdown]
# ### 1. See the below picture and create the exact table with exact formatting. Font – ‘Times New Roman’ Size – 14, Color of first line Orange.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Ans:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. From the above table use Sum Formula and find the total for each student.

# %% [markdown]
# #### Ans:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Calculate Average for each student in the next row. Use Formulas.

# %% [markdown]
# #### Ans:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4. Calculate Rank for each student. Use Formulas.

# %% [markdown]
# #### Ans:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 5. Calculate Percentage for each student. Use Formulas. Round off the decimals up to 2 points.

# %% [markdown]
# #### Ans:
# ![image.png](attachment:image.png)
